# %% [markdown]
# # Load dataset

# %%
import pandas as pd
df = pd.read_csv('Smoking Data.csv')

# %%
df.head()
# Out:
#       region  age     sex     bmi  children smoker
# 0  southwest   19  female  27.900         0    yes
# 1  southeast   18    male  33.770         1     no
# 2  southeast   28    male  33.000         3     no
# 3  northwest   33    male  22.705         0     no
# 4  northwest   32    male  28.880         0     no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   region    1338 non-null   object
#  1   age       1338 non-null   int64
#  2   sex       1338 non-null   object
#  3   bmi       1338 non-null   float64
#  4   children  1338 non-null   int64
#  5   smoker    1338 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 62.8+ KB

# %% [markdown]
# # String to number using LebelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df.region = le.fit_transform(df['region'])
df.sex = le.fit_transform(df['sex'])
df.smoker = le.fit_transform(df['smoker'])

# %%
df.head()
# Out:
#    region  age  sex     bmi  children  smoker
# 0       3   19    0  27.900         0       1
# 1       2   18    1  33.770         1       0
# 2       2   28    1  33.000         3       0
# 3       1   33    1  22.705         0       0
# 4       1   32    1  28.880         0       0

# %%
x = df.drop('smoker', axis=1)

# %%
y = df['smoker']

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split as tts
xtrain, xtest, ytrain, ytest = tts(x, y, test_size=0.30, random_state= 42)

# %%
xtrain.shape
# Out:
# (936, 5)

# %%
xtest.shape
# Out:
# (402, 5)

# %%
ytrain.shape
# Out:
# (936,)

# %%
ytest.shape
# Out:
# (402,)

# %%
xtest
# Out:
#       region  age  sex     bmi  children
# 764        0   45    0  25.175         2
# 887        1   36    0  30.020         0
# 890        1   64    0  26.885         0
# 1293       1   46    1  25.745         3
# 259        1   19    1  31.920         0
# ...      ...  ...  ...     ...       ...
# 701        0   50    0  44.745         0
# 672        2   36    1  29.700         0
# 1163       0   18    0  28.215         0
# 1103       2   58    1  36.080         0
# 1295       3   20    1  22.000         1
#
# [402 rows x 5 columns]

# %%
ytest
# Out:
# 764     0
# 887     0
# 890     1
# 1293    0
# 259     1
#        ..
# 701     0
# 672     0
# 1163    0
# 1103    0
# 1295    0
# Name: smoker, Length: 402, dtype: int32

# %% [markdown]
# # Applying the RandomForestClassifier model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier()

# %%
clf.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier()

# %%
clf.score(xtest, ytest)
# Out:
# 0.7786069651741293

# %% [markdown]
# # Hyper Parameter Tuning

# %%
import numpy as np
trees = np.random.randint(25,200, 25)
trees
# Out:
# array([ 35, 126, 114,  75,  83,  82, 176, 139, 105,  69, 117,  33, 172,
#        127, 198,  44,  97, 129, 103,  39, 153, 121, 164,  87,  37])

# %% [markdown]
# # RF_GridSearchCV

# %%
criterion = ['gini', 'entropy','log_loss']
max_depth = np.random.randint(1,8,25)
min_samples_split = [2,3,4]
max_features = ['auto', 'sqrt', 'log2']

# %%
ids = {
'n_estimators': trees,
'criterion' : criterion,
'min_samples_split': min_samples_split,
'max_depth': max_depth,
'max_features': max_features
    
}

# %%
print(ids)
# Out:
# {'n_estimators': array([ 35, 126, 114,  75,  83,  82, 176, 139, 105,  69, 117,  33, 172,
#        127, 198,  44,  97, 129, 103,  39, 153, 121, 164,  87,  37]), 'criterion': ['gini', 'entropy', 'log_loss'], 'min_samples_split': [2, 3, 4], 'max_depth': array([5, 2, 6, 7, 6, 4, 3, 6, 6, 2, 1, 1, 5, 5, 2, 6, 6, 3, 5, 7, 2, 7,
#        2, 6, 7]), 'max_features': ['auto', 'sqrt', 'log2']}

# %% [markdown]
# # GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
rgcv = GridSearchCV(clf, ids, n_jobs=5, cv=3)

# %%
rgcv.fit(xtrain, ytrain)
# Out:
# C:\Users\MY\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.78846154 0.79059829 0.78952991 ...        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=5,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': array([5, 2, 6, 7, 6, 4, 3, 6, 6, 2, 1, 1, 5, 5, 2, 6, 6, 3, 5, 7, 2, 7,
#        2, 6, 7]),
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': array([ 35, 126, 114,  75,  83,  82, 176, 139, 105,  69, 117,  33, 172,
#        127, 198,  44,  97, 129, 103,  39, 153, 121, 164,  87,  37])})

# %%
rgcv.cv_results_
# Out:
# {'mean_fit_time': array([0.06769252, 0.23432088, 0.18224835, ..., 0.0833145 , 0.04165729,
#         0.01562103]),
#  'std_fit_time': array([0.00736423, 0.02209203, 0.0194824 , ..., 0.01472785, 0.00736412,
#         0.01275416]),
#  'mean_score_time': array([0.00520722, 0.01562015, 0.01041436, ..., 0.        , 0.        ,
#         0.        ]),
#  'std_score_time': array([7.36412216e-03, 1.80877156e-06, 7.36406597e-03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', ..., 'log_loss', 'log_loss',
#                     'log_loss'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[5, 5, 5, ..., 7, 7, 7],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=['auto', 'auto', 'auto', ..., 'log2', 'log2', 'log2'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[2, 2, 2, ..., 4, 4, 4],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[35, 126, 114, ..., 164, 87, 37],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 3,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'sqrt',
#    'min_samples_split': 4,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 2,
# ...
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 3,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 7,
#    'max_features': 'log2',
#    'min_samples_split': 4,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 2,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 3,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'auto',
#    'min_samples_split': 4,
#    'n_estimators': 37},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 35},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 126},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 114},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 75},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 83},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 82},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 176},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 139},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 105},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 69},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 117},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 33},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 172},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 127},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 198},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 44},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 97},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 129},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 103},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 39},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 153},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 121},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 164},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 87},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'n_estimators': 37},
#   ...],
#  'split0_test_score': array([0.79166667, 0.79166667, 0.79166667, ...,        nan,        nan,
#                nan]),
#  'split1_test_score': array([0.78205128, 0.78846154, 0.78525641, ...,        nan,        nan,
#                nan]),
#  'split2_test_score': array([0.79166667, 0.79166667, 0.79166667, ...,        nan,        nan,
#                nan]),
#  'mean_test_score': array([0.78846154, 0.79059829, 0.78952991, ...,        nan,        nan,
#                nan]),
#  'std_test_score': array([0.00453274, 0.00151091, 0.00302182, ...,        nan,        nan,
#                nan]),
#  'rank_test_score': array([ 7321,  4238,  5294, ..., 13119, 15004, 16875])}

# %%
cv_results = pd.DataFrame(rgcv.cv_results_)
cv_results
# Out:
#        mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0           0.067693      0.007364         0.005207        0.007364
# 1           0.234321      0.022092         0.015620        0.000002
# 2           0.182248      0.019482         0.010414        0.007364
# 3           0.124970      0.012755         0.010414        0.007364
# 4           0.130178      0.007364         0.010414        0.007364
# ...              ...           ...              ...             ...
# 16870       0.072899      0.019482         0.000000        0.000000
# 16871       0.046864      0.000002         0.000000        0.000000
# 16872       0.083314      0.014728         0.000000        0.000000
# 16873       0.041657      0.007364         0.000000        0.000000
# 16874       0.015621      0.012754         0.000000        0.000000
#
#       param_criterion param_max_depth param_max_features  \
# 0                gini               5               auto
# 1                gini               5               auto
# 2                gini               5               auto
# 3                gini               5               auto
# 4                gini               5               auto
# ...               ...             ...                ...
# 16870        log_loss               7               log2
# 16871        log_loss               7               log2
# 16872        log_loss               7               log2
# 16873        log_loss               7               log2
# 16874        log_loss               7               log2
#
#       param_min_samples_split param_n_estimators  \
# 0                           2                 35
# 1                           2                126
# 2                           2                114
# 3                           2                 75
# 4                           2                 83
# ...                       ...                ...
# 16870                       4                153
# 16871                       4                121
# 16872                       4                164
# 16873                       4                 87
# 16874                       4                 37
#
#                                                   params  split0_test_score  \
# 0      {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.791667
# 1      {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.791667
# 2      {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.791667
# 3      {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.791667
# 4      {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.791667
# ...                                                  ...                ...
# 16870  {'criterion': 'log_loss', 'max_depth': 7, 'max...                NaN
# 16871  {'criterion': 'log_loss', 'max_depth': 7, 'max...                NaN
# 16872  {'criterion': 'log_loss', 'max_depth': 7, 'max...                NaN
# 16873  {'criterion': 'log_loss', 'max_depth': 7, 'max...                NaN
# 16874  {'criterion': 'log_loss', 'max_depth': 7, 'max...                NaN
#
#        split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0               0.782051           0.791667         0.788462        0.004533
# 1               0.788462           0.791667         0.790598        0.001511
# 2               0.785256           0.791667         0.789530        0.003022
# 3               0.782051           0.791667         0.788462        0.004533
# 4               0.788462           0.791667         0.790598        0.001511
# ...                  ...                ...              ...             ...
# 16870                NaN                NaN              NaN             NaN
# 16871                NaN                NaN              NaN             NaN
# 16872                NaN                NaN              NaN             NaN
# 16873                NaN                NaN              NaN             NaN
# 16874                NaN                NaN              NaN             NaN
#
#        rank_test_score
# 0                 7321
# 1                 4238
# 2                 5294
# 3                 7321
# 4                 4238
# ...                ...
# 16870            13121
# 16871            13120
# 16872            13119
# 16873            15004
# 16874            16875
#
# [16875 rows x 16 columns]

# %%
rgcv.best_score_
# Out:
# 0.7927350427350427

# %%
rgcv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': 'log2',
#  'min_samples_split': 3,
#  'n_estimators': 35}

# %%
clf2 = RandomForestClassifier(criterion = 'gini',
 max_depth = 4,
 max_features = 'log2',
 min_samples_split = 3,
 n_estimators = 35)

# %%
print(clf2)
# Out:
# RandomForestClassifier(max_depth=4, max_features='log2', min_samples_split=3,
#                        n_estimators=35)

# %%
rgcv.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, max_features='log2',
#                        min_samples_split=3, n_estimators=35)

# %%
clf2.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(max_depth=4, max_features='log2', min_samples_split=3,
#                        n_estimators=35)

# %% [markdown]
# # Accuracy

# %%
clf2.score(xtest, ytest)
# Out:
# 0.8034825870646766
